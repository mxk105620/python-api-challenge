# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
#city_data_df = pd.read_csv(".../output_data/cities.csv")
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot using hvplot
map_plot = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo= True,
    size='Humidity',
    scale= 1,
    color="City",
    alpha=0.5,
    titles="OSM",
    frame_width=600,
    frame_height=400
)

# Display the map
map_plot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Configure the map plot using hvplot
# ----> 2 map_plot = city_data_df.hvplot.points(
#       3     'Lng',
#       4     'Lat',
#       5     geo= True,
#       6     size='Humidity',
#       7     scale=1,
#       8     color="City",
#       9     alpha=0.5,
#      10     titles="OSM",
#      11     frame_width=600,
#      12     frame_height=400
#      13 )
#      15 # Display the map
#      16 map_plot
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/plotting/core.py:1626, in hvPlotTabular.points(self, x, y, **kwds)
#    1568 def points(self, x=None, y=None, **kwds):
#    1569     """
#    1570     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1571     geographic plots.
#    (...)
#    1624     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1625     """
# -> 1626     return self(x, y, kind="points", **kwds)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/plotting/core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/plotting/core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/converter.py:401, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     399 self.dynamic = dynamic
#     400 self.geo = any([geo, crs, global_extent, projection, project, coastline, features, tiles])
# --> 401 self.crs = self._process_crs(data, crs) if self.geo else None
#     402 self.project = project
#     403 self.coastline = coastline
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/converter.py:662, in HoloViewsConverter._process_crs(self, data, crs)
#     659     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     661 try:
# --> 662     return process_crs(_crs)
#     663 except ValueError:
#     664     # only raise error if crs was specified in kwargs
#     665     if crs:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/hvplot/util.py:248, in process_crs(crs)
#     246     missing.append('pyproj')
#     247 if missing:
# --> 248     raise ImportError(f'Geographic projection support requires: {", ".join(missing)}.')
#     250 if crs is None:
#     251     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires: cartopy, geoviews, pyproj.

# %%
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Define conditions for filtering
# Convert temperature from Kelvin to Celsius
city_data_df['Max Temp (°C)'] = city_data_df['Max Temp'] - 273.15

# Define conditions for filtering
max_temp_condition = city_data_df['Max Temp (°C)'] < 25  # Maximum temperature less than 25°C
humidity_condition = city_data_df['Humidity'] < 50  # Humidity less than 50%
cloudiness_condition = city_data_df['Cloudiness'] < 30  # Cloudiness less than 30%
wind_speed_condition = city_data_df['Wind Speed'] < 10  # Wind speed less than 10 m/s

# Filter cities based on conditions
narrowed_city_df = city_data_df[max_temp_condition & humidity_condition & cloudiness_condition & wind_speed_condition]

# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna(how='any')

# Reset index
narrowed_city_df.reset_index(drop=True, inplace=True)

# Display sample data
narrowed_city_df
# Out:
#     City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0         0                faya  18.3851   42.4509     22.06        35
# 1        22          guiratinga -16.3494  -53.7583     38.35        14
# 2        29         saint-louis  16.3333  -15.0000     38.80        24
# 3        44        collierville  35.0420  -89.6645      7.11        47
# 4        73               nalut  30.3333   10.8500     25.41        27
# 5        90        saint george  37.1041 -113.5841     13.33        44
# 6        96             zhangye  38.9342  100.4517     11.11        16
# 7       101               heihe  50.2441  127.4902      2.32        49
# 8       115          cedar city  37.6775 -113.0619     14.11        49
# 9       141             brenham  30.1669  -96.3977     14.47        40
# 10      158            almaznyy  48.0448   40.0450     10.39        47
# 11      174               avera  33.1940  -82.5271     12.53        26
# 12      176          challapata -18.9000  -66.7667     14.15        30
# 13      186            upington -28.4478   21.2561     32.21        19
# 14      231          carrollton  32.9537  -96.8903     14.63        31
# 15      243    russkaya polyana  49.4170   31.9201     12.87        32
# 16      258  comodoro rivadavia -45.8667  -67.5000     25.92        24
# 17      268             chengde  40.9725  117.9361      5.17        26
# 18      296                jalu  29.0331   21.5482     22.33        37
# 19      305             kingman  35.1894 -114.0530     20.07        49
# 20      331          swan river  52.1058 -101.2676      0.94        40
# 21      359               korla  41.7597   86.1469     13.51        19
# 22      387      ribeira grande  38.5167  -28.7000     19.22        48
# 23      428               aktau  43.6500   51.2000     10.32        46
# 24      436        lakki marwat  32.6079   70.9114     27.89        20
# 25      441         yangliuqing  39.1375  116.9997      7.97        31
# 26      476             chifeng  42.2683  118.9636      5.09        20
# 27      477           caiaponia -16.9567  -51.8103     36.72        14
# 28      481           abu zabad  12.3500   29.2500     31.09        29
# 29      495         statesville  35.7826  -80.8873     10.76        49
# 30      496              tikrit  34.6071   43.6782     29.02        14
# 31      522             xuchang  34.0167  113.8167     12.46        35
# 32      532          mandalgovi  45.7625  106.2708      6.23        23
# 33      537            tongliao  43.6125  122.2653      3.54        35
# 34      542               bilma  18.6853   12.9164     31.90        18
# 35      550                pali  25.7667   73.3333     27.18        26
# 36      560             changli  39.7042  119.1506      9.17        33
#
#     Cloudiness  Wind Speed Country        Date  Max Temp (°C)
# 0           21        2.60      SA  1666108228        -251.09
# 1           22        3.10      BR  1666108243        -234.80
# 2            4        1.78      SN  1666108247        -234.35
# 3            0        5.66      US  1666108151        -266.04
# 4            0        5.11      LY  1666108275        -247.74
# 5            0        1.54      US  1666108286        -259.82
# 6            0        1.67      CN  1666108292        -262.04
# 7            3        3.14      CN  1666108295        -270.83
# 8            0        0.00      US  1666108304        -259.04
# 9            0        3.09      US  1666108319        -258.68
# 10          15        3.44      RU  1666108332        -262.76
# 11           0        4.90      US  1666108342        -260.62
# 12           0        5.26      BO  1666108343        -259.00
# 13          20        3.09      ZA  1666108351        -240.94
# 14           0        5.66      US  1666108361        -258.52
# 15          10        3.97      UA  1666108380        -260.28
# 16           0        7.20      AR  1666108389        -247.23
# 17           0        0.63      CN  1666108395        -267.98
# 18          25        3.89      LY  1666108413        -250.82
# 19           5        4.02      US  1666108417        -253.08
# 20           0        2.06      CA  1666108431        -272.21
# 21          27        1.37      CN  1666108447        -259.64
# 22          20        8.75      PT  1666108463        -253.93
# 23           0        3.91      KZ  1666108486        -262.83
# 24           0        1.53      PK  1666108492        -245.26
# 25           0        3.58      CN  1666108494        -265.18
# 26           0        2.81      CN  1666108512        -268.06
# 27          26        4.07      BR  1666108513        -236.43
# 28          16        1.28      SD  1666108516        -242.06
# 29           0        4.63      US  1666108414        -262.39
# 30           0        1.41      IQ  1666108524        -244.13
# 31           0        3.02      CN  1666108539        -260.69
# 32           7        2.94      MN  1666108544        -266.92
# 33           0        3.55      CN  1666108546        -269.61
# 34           0        4.17      NE  1666108548        -241.25
# 35           0        1.38      IN  1666108552        -245.97
# 36           0        2.41      CN  1666108557        -263.98

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowed_city_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''


# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat      Lng  Humidity Hotel Name
# 0          faya      SA  18.3851  42.4509        35
# 1    guiratinga      BR -16.3494 -53.7583        14
# 2   saint-louis      SN  16.3333 -15.0000        24
# 3  collierville      US  35.0420 -89.6645        47
# 4         nalut      LY  30.3333  10.8500        27

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    response= requests.get(base_url, params=params)
    # Make and API request using the params dictionaty
    name_address = response.json()
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# faya - nearest hotel: No hotel found
# guiratinga - nearest hotel: No hotel found
# saint-louis - nearest hotel: No hotel found
# collierville - nearest hotel: Days Inn & Suites by Wyndham Collierville Germantown Area
# nalut - nearest hotel: No hotel found
# saint george - nearest hotel: The Advenire, an Autograph Collection Hotel
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# heihe - nearest hotel: Санкт-Петербург
# cedar city - nearest hotel: Baymont Inn & Suites
# brenham - nearest hotel: Ant Street Inn
# almaznyy - nearest hotel: Зверево
# avera - nearest hotel: No hotel found
# challapata - nearest hotel: Residencial Marian
# upington - nearest hotel: Die Eiland Holiday Ressort
# carrollton - nearest hotel: Days Inn North Dallas/Farmers Branch
# russkaya polyana - nearest hotel: No hotel found
# comodoro rivadavia - nearest hotel: No hotel found
# chengde - nearest hotel: 紫御国际假日酒店
# jalu - nearest hotel: فندق جالو السياحي
# kingman - nearest hotel: Home2 Suites by Hilton Kingman
# swan river - nearest hotel: Swan River Super 8
# korla - nearest hotel: Silver Star Hotel
# ribeira grande - nearest hotel: Hospedaria JSF
# aktau - nearest hotel: Гульдана
# lakki marwat - nearest hotel: No hotel found
# yangliuqing - nearest hotel: IU Inn
# chifeng - nearest hotel: 心连心酒店
# caiaponia - nearest hotel: No hotel found
# abu zabad - nearest hotel: No hotel found
# statesville - nearest hotel: The Kerr House Bed & Breakfast
# tikrit - nearest hotel: فندق بلازا
# xuchang - nearest hotel: first hotel
# mandalgovi - nearest hotel: Б
# tongliao - nearest hotel: No hotel found
# bilma - nearest hotel: No hotel found
# pali - nearest hotel: Hotel Pawan International
# changli - nearest hotel: 客房
#                   City Country      Lat       Lng  Humidity  \
# 0                 faya      SA  18.3851   42.4509        35
# 1           guiratinga      BR -16.3494  -53.7583        14
# 2          saint-louis      SN  16.3333  -15.0000        24
# 3         collierville      US  35.0420  -89.6645        47
# 4                nalut      LY  30.3333   10.8500        27
# 5         saint george      US  37.1041 -113.5841        44
# 6              zhangye      CN  38.9342  100.4517        16
# 7                heihe      CN  50.2441  127.4902        49
# 8           cedar city      US  37.6775 -113.0619        49
# 9              brenham      US  30.1669  -96.3977        40
# 10            almaznyy      RU  48.0448   40.0450        47
# 11               avera      US  33.1940  -82.5271        26
# 12          challapata      BO -18.9000  -66.7667        30
# 13            upington      ZA -28.4478   21.2561        19
# 14          carrollton      US  32.9537  -96.8903        31
# 15    russkaya polyana      UA  49.4170   31.9201        32
# 16  comodoro rivadavia      AR -45.8667  -67.5000        24
# 17             chengde      CN  40.9725  117.9361        26
# 18                jalu      LY  29.0331   21.5482        37
# 19             kingman      US  35.1894 -114.0530        49
# 20          swan river      CA  52.1058 -101.2676        40
# 21               korla      CN  41.7597   86.1469        19
# 22      ribeira grande      PT  38.5167  -28.7000        48
# 23               aktau      KZ  43.6500   51.2000        46
# 24        lakki marwat      PK  32.6079   70.9114        20
# 25         yangliuqing      CN  39.1375  116.9997        31
# 26             chifeng      CN  42.2683  118.9636        20
# 27           caiaponia      BR -16.9567  -51.8103        14
# 28           abu zabad      SD  12.3500   29.2500        29
# 29         statesville      US  35.7826  -80.8873        49
# 30              tikrit      IQ  34.6071   43.6782        14
# 31             xuchang      CN  34.0167  113.8167        35
# 32          mandalgovi      MN  45.7625  106.2708        23
# 33            tongliao      CN  43.6125  122.2653        35
# 34               bilma      NE  18.6853   12.9164        18
# 35                pali      IN  25.7667   73.3333        26
# 36             changli      CN  39.7042  119.1506        33
#
#                                            Hotel Name
# 0                                      No hotel found
# 1                                      No hotel found
# 2                                      No hotel found
# 3   Days Inn & Suites by Wyndham Collierville Germ...
# 4                                      No hotel found
# 5         The Advenire, an Autograph Collection Hotel
# 6                                  Zhangye Hotel 张掖饭店
# 7                                     Санкт-Петербург
# 8                                Baymont Inn & Suites
# 9                                      Ant Street Inn
# 10                                            Зверево
# 11                                     No hotel found
# 12                                 Residencial Marian
# 13                         Die Eiland Holiday Ressort
# 14               Days Inn North Dallas/Farmers Branch
# 15                                     No hotel found
# 16                                     No hotel found
# 17                                           紫御国际假日酒店
# 18                                  فندق جالو السياحي
# 19                     Home2 Suites by Hilton Kingman
# 20                                 Swan River Super 8
# 21                                  Silver Star Hotel
# 22                                     Hospedaria JSF
# 23                                           Гульдана
# 24                                     No hotel found
# 25                                             IU Inn
# 26                                              心连心酒店
# 27                                     No hotel found
# 28                                     No hotel found
# 29                     The Kerr House Bed & Breakfast
# 30                                         فندق بلازا
# 31                                        first hotel
# 32                                                  Б
# 33                                     No hotel found
# 34                                     No hotel found
# 35                          Hotel Pawan International
# 36                                                 客房

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    hover_cols = ["Hotel Name", "Country"],
    frame_width = 700,
    frame_height = 500
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
